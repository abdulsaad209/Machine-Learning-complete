# %% [markdown]
# # Overfitting

# %% [markdown]
# Overfitting & Underfitting is happened in **Depth Parameter** Generally!

# %% [markdown]
# <img src='images/depth parameter.png' width="300" />

# %% [markdown]
# ***Inner Node and Leaf Node combine are called as Depth of Tree***

# %% [markdown]
# <img title='Overfitting' src='images/Overfitting.png' height=600 width=600 />

# %% [markdown]
# # Underfitting

# %% [markdown]
# <img title='Underfitting' src='images/Underfitting.png' width=600 />

# %% [markdown]
# <img title='Underfitting Geometrical Intuition' src='images/Underfitting Geometrical Intuition.png' width=600 />

# %% [markdown]
# ***We can handle the Overfitting and Underfitting by handle the Hypertuning Parameters value. When max-depth is more then there would be the chance of overfitting and if value of max-depth is less then it would be underfitting.***

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
# %matplotlib inline

# %%
pd.read_csv('images/Social_Network_Ads(1).csv').head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
def analyzer(Max_Depth):
    data = pd.read_csv('images/Social_Network_Ads(1).csv')
    X = data.iloc[:, 2:4].values
    y = data.iloc[:, -1].values
    
    clf = DecisionTreeClassifier(max_depth=Max_Depth)
    clf.fit(X,y)
    
    a = np.arange(start=X[:, 0].min()-1, stop=X[:, 0].max()+1, step=0.1)
    b = np.arange(start=X[:, 1].min()-1, stop=X[:, 1].max()+1, step=100)
    
    XX,YY = np.meshgrid(a,b)
    
    input_array = np.array([XX.ravel(), YY.ravel()]).T
    
    labels = clf.predict(input_array)
    
    plt.contourf(XX, YY, labels.reshape(XX.shape), alpha=0.5)
    plt.scatter(X[:,0],X[:,1], c=y)

# %%
analyzer(Max_Depth=None) # Overfitting Case

# %%
analyzer(Max_Depth=1)

# %%
analyzer(Max_Depth=2)

# %%
analyzer(Max_Depth=4)

# %%
analyzer(Max_Depth=5)

# %% [markdown]
# # Tool

# %% [markdown]
# [Decision Tree Classifier Tool](https://dt-visualise.herokuapp.com/)
