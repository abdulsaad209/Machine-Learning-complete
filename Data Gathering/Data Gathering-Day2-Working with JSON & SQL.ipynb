# %% [markdown]
# ## ***JavaScript Object Notation***
# JavaScript Object Notation (JSON) is a standard text-based format for representing structured data based on JavaScript object syntax. It is commonly used for transmitting data in web applications (e.g., sending some data from the server to the client, so it can be displayed on a web page, or vice versa).

# %%
import pandas as pd

# %% [markdown]
# # ***Working with JSON***

# %%
pd.read_json('Dataset/recipe.json')
# Out:
#           id      cuisine                                        ingredients
# 0      10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1      25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2      20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3      22213       indian                [water, vegetable oil, wheat, salt]
# 4      13162       indian  [black pepper, shallots, cornflour, cayenne pe...
# ...      ...          ...                                                ...
# 39769  29109        irish  [light brown sugar, granulated sugar, butter, ...
# 39770  11462      italian  [KRAFT Zesty Italian Dressing, purple onion, b...
# 39771   2238        irish  [eggs, citrus fruit, raisins, sourdough starte...
# 39772  41882      chinese  [boneless chicken skinless thigh, minced garli...
# 39773   2362      mexican  [green chile, jalapeno chilies, onions, ground...
#
# [39774 rows x 3 columns]

# %%
pd.read_json("https://raw.githubusercontent.com/simonw/datasette/main/package.json")
# Out:
#                name  private devDependencies  \
# prettier  datasette     True          ^2.2.1
# fix       datasette     True             NaN
#
#                                           scripts
# prettier  prettier 'datasette/static/*[!.min].js'
# fix                   npm run prettier -- --write

# %%
pd.read_json("https://raw.githubusercontent.com/ozlerhakan/mongodb-json-files/master/datasets/products.json",
            lines=True).head()
# Out:
#                                     _id                     name brand  \
# 0                                   ac3                AC3 Phone  ACME
# 1                                   ac7                AC7 Phone  ACME
# 2  {'$oid': '507d95d5719dbef170f15bf9'}       AC3 Series Charger   NaN
# 3  {'$oid': '507d95d5719dbef170f15bfa'}           AC3 Case Green   NaN
# 4  {'$oid': '507d95d5719dbef170f15bfb'}  Phone Extended Warranty   NaN
#
#                    type  price  rating  warranty_years  available  \
# 0                 phone  200.0     3.8            1.00        1.0
# 1                 phone  320.0     4.0            1.00        0.0
# 2  [accessory, charger]   19.0     2.8            0.25        NaN
# 3     [accessory, case]   12.0     1.0            0.00        NaN
# 4              warranty   38.0     5.0            2.00        NaN
#
#                               for  color  monthly_price limits  term_years  \
# 0                             NaN    NaN            NaN    NaN         NaN
# 1                             NaN    NaN            NaN    NaN         NaN
# 2                 [ac3, ac7, ac9]    NaN            NaN    NaN         NaN
# 3                             NaN  green            NaN    NaN         NaN
# 4  [ac3, ac7, ac9, qp7, qp8, qp9]    NaN            NaN    NaN         NaN
#
#    sales_tax  cancel_penalty additional_tarriffs
# 0        NaN             NaN                 NaN
# 1        NaN             NaN                 NaN
# 2        NaN             NaN                 NaN
# 3        NaN             NaN                 NaN
# 4        NaN             NaN                 NaN

# %%
#import json
#file = open('Dataset/recipe.json')
#file.read()

# %% [markdown]
# # ***Working with SQL***

# %%
# Now i need to convert the sql formate into pandas so here i need i library called
# mysql.connector so first i install it
# so let's install it

# %%
# !pip install mysql.connector
# Out:
# Requirement already satisfied: mysql.connector in /home/saad/anaconda3/lib/python3.8/site-packages (2.2.9)

# %%
# so library installation is done Let's call it
import mysql.connector

# %%
# no i create a connection through python to our database

conn = mysql.connector.connect(host='localhost', user='root', password='', database='world') # store in a variable

# host = API from where i getting the data
# user = normally in starting the user name has root
# password = now here password is empty because i didn't set yet any password
# database = name of data base from where you want to get the data

# %%
pd.read_sql_query("SELECT * FROM city", conn) # generally we need to tell it two things
# 1.sql query
# 2. connection object
# Out:
#         ID            Name CountryCode       District  Population
# 0        1           Kabul         AFG          Kabol     1780000
# 1        2        Qandahar         AFG       Qandahar      237500
# 2        3           Herat         AFG          Herat      186800
# 3        4  Mazar-e-Sharif         AFG          Balkh      127800
# 4        5       Amsterdam         NLD  Noord-Holland      731200
# ...    ...             ...         ...            ...         ...
# 4074  4075      Khan Yunis         PSE     Khan Yunis      123175
# 4075  4076          Hebron         PSE         Hebron      119401
# 4076  4077        Jabaliya         PSE     North Gaza      113901
# 4077  4078          Nablus         PSE         Nablus      100231
# 4078  4079           Rafah         PSE          Rafah       92020
#
# [4079 rows x 5 columns]

# %%
pd.read_sql_query("SELECT * FROM city WHERE CountryCode LIKE 'PAK'", conn).head()
# Out:
#      ID        Name CountryCode District  Population
# 0  2822     Karachi         PAK    Sindh     9269265
# 1  2823      Lahore         PAK   Punjab     5063499
# 2  2824  Faisalabad         PAK   Punjab     1977246
# 3  2825  Rawalpindi         PAK   Punjab     1406214
# 4  2826      Multan         PAK   Punjab     1182441

# %%
pd.read_sql_query("SELECT * FROM country WHERE LifeExpectancy>60", conn)
# Out:
#     Code                  Name      Continent           Region  SurfaceArea  \
# 0    ABW                 Aruba  North America        Caribbean        193.0
# 1    AIA              Anguilla  North America        Caribbean         96.0
# 2    ALB               Albania         Europe  Southern Europe      28748.0
# 3    AND               Andorra         Europe  Southern Europe        468.0
# 4    ANT  Netherlands Antilles  North America        Caribbean        800.0
# ..   ...                   ...            ...              ...          ...
# 162  VIR  Virgin Islands, U.S.  North America        Caribbean        347.0
# 163  VNM               Vietnam           Asia   Southeast Asia     331689.0
# 164  VUT               Vanuatu        Oceania        Melanesia      12189.0
# 165  WSM                 Samoa        Oceania        Polynesia       2831.0
# 166  YUG            Yugoslavia         Europe  Southern Europe     102173.0
#
#      IndepYear  Population  LifeExpectancy      GNP   GNPOld  \
# 0          NaN      103000            78.4    828.0    793.0
# 1          NaN        8000            76.1     63.2      NaN
# 2       1912.0     3401200            71.6   3205.0   2500.0
# 3       1278.0       78000            83.5   1630.0      NaN
# 4          NaN      217000            74.7   1941.0      NaN
# ..         ...         ...             ...      ...      ...
# 162        NaN       93000            78.1      0.0      NaN
# 163     1945.0    79832000            69.3  21929.0  22834.0
# 164     1980.0      190000            60.6    261.0    246.0
# 165     1962.0      180000            69.2    141.0    157.0
# 166     1918.0    10640000            72.4  17000.0      NaN
#
#                                LocalName  \
# 0                                  Aruba
# 1                               Anguilla
# 2                              Shqipëria
# 3                                Andorra
# 4                   Nederlandse Antillen
# ..                                   ...
# 162  Virgin Islands of the United States
# 163                             Viêt Nam
# 164                              Vanuatu
# 165                                Samoa
# 166                          Jugoslavija
#
#                                    GovernmentForm             HeadOfState  \
# 0    Nonmetropolitan Territory of The Netherlands                 Beatrix
# 1                   Dependent Territory of the UK            Elisabeth II
# 2                                        Republic          Rexhep Mejdani
# 3                    Parliamentary Coprincipality
# 4    Nonmetropolitan Territory of The Netherlands                 Beatrix
# ..                                            ...                     ...
# 162                                  US Territory          George W. Bush
# 163                          Socialistic Republic          Trân Duc Luong
# 164                                      Republic               John Bani
# 165                         Parlementary Monarchy  Malietoa Tanumafili II
# 166                              Federal Republic      Vojislav Koštunica
#
#      Capital Code2
# 0        129    AW
# 1         62    AI
# 2         34    AL
# 3         55    AD
# 4         33    AN
# ..       ...   ...
# 162     4067    VI
# 163     3770    VN
# 164     3537    VU
# 165     3169    WS
# 166     1792    YU
#
# [167 rows x 15 columns]
